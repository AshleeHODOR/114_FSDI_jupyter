# %% [markdown]
# Solutions to previous problems

# %%
Class QueueII:
    class __Node:
        def __init__(self, datum):
            self.data = datum
            self.next = None

        def __init__(self):
            self.back = None
            self.front = None
            self.count = 0

        def enqueue(self, element):
            new_node = self.__Node(element)
            self.count += 1
            if not self.back:
                self.back = new_node
                self.front = new_node
            else:
                self.back.next = New_node
                self.back = new_node
        
        def dequeue(self):
            if self.front:
                backup = self.front.data 
                self.front = self.front.next
                self.count -= 1
                if not self.front:
                    self.back = None
                return backup
            raise IndexError("Queue is empty")

            # Nice to have methods
            def peek(self):
                if self.front:
                    self.front.data
                else:
                    raise IndexError("Queue is empty")

            def is_empty(self):
                return self.front == None

            def __str__(self):
                out = "["
                if self.front:
                    current = self.front
                    out += "%s" % current.data
                    current = current.next
                    while current:
                        out += ", %s" % current.data
                        current = current.next
                out += "]"
                return out
# Out:
#   Cell In[6], line 1
#     Class QueueII:
#           ^
# SyntaxError: invalid syntax

# %%
Queue = QueueII()

for number in range(11):
    queue.enqueue(number)

print(queue)

while not queue.is_empty():
    print("Dequeued: %s" % queue.dequeue())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Queue = QueueII()
#       3 for number in range(11):
#       4     queue.enqueue(number)
#
# NameError: name 'QueueII' is not defined

# %%
Class singlyLinkedList:
    class __Node:
        def __init__(self, datum):
            self.data = datum
            self.next = None

    def __init__(self):
        self.head = None
        self.tail = None

#worst case tc 0(1)
#0(1) 

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail= new_node

    def pop(self):
        if self.tail:
            backup = self.tail.data
            current = self.head
            prev = None
            if self.tail == self.head:
                self.tail = None
                self.head = None
                return backup
            while current != self.tail:
                prev = current
                current = current.next
            self.tail = prev
            prev.next = None
            return backup
            
        raise IndexError("List is empty")
        
    def remove(self, value):
       if self.head:
            current = self.head
           prev = None
            found = False
            while current.next and not found:
                if current.data == value:
                    found = True 
                else:
                    prev = current
                    current = current.next
            if prev:
                prev.next = current.next
                if current == self.tail:
                    self.tail = prev
            else:
                self.head = self.head.next
                if not self.head:
                    self.tails = None
                      else:
        raise ValueError("Value not found in list")


# HOMEWORK: 
    def insert(self, index, value):
    # The insert method allows the caller to insert a new node the "value" (the param to this method) BEFORE the target index. 
    # The index is 0 the new node replaces the head
    # If the index exceeds the length of the list, the operation requested is equivalent to an "append". Other, insert the new node before the target index.
    new _node = self.__Node(value)
    if index == 0 or not self.head:
        # self.append(value)
        self.head = new_node
        if not self.tail:
            self.tail = new_node
    else:
        current = self.head
        prev = None
        count = 0
        found = False
        while current.next and not found:
            if count = index:
            found = False
            else:
                prev = current
                current = current.next
        if found:
            new_node.next = prev.next
            prev.next = new_node
        else:
            self.append(value)
        

 
#END HOMEWORK 

    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % current.data
            current = current.next
            while current:
                out += ", %s" % current.data
                current = current.next
        out += "]"

 def __len__(self):
        count = 0
        current = self.head
        while current:
            count += 1
            current = current.next
        return count
# Out:
#   File <string>:44
#     prev = None
#                ^
# IndentationError: unindent does not match any outer indentation level

# %%
Class DoublyLinkedList:
    class __Node:
        def __init__(self, datum):
            self.data = datum
            self.next = None

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail= new_node
    
    def pop(self):
        if self.tail:
            backup = self.tail.data
            self.tail = self.tail.prev
            self.tail.next = None
            return backup
        raise IndexError("List is empty")                   
        
    def remove(self, value):
       # TODO: Implement remove on your doubly linked list. 
        pass

    def insert(self, index, value):
    # TODO: Update insert for doubly linked list
    new _node = self.__Node(value)
    if index == 0 or not self.head:
        # self.append(value)
        self.head = new_node
        if not self.tail:
            self.tail = new_node
    else:
        current = self.head
        prev = None
        count = 0
        found = False
        while current.next and not found:
            if count = index:
            found = False
            else:
                prev = current
                current = current.next
        if found:
            new_node.next = prev.next
            prev.next = new_node
        else:
            self.append(value)

    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % current.data
            current = current.next
            while current:
                out += ", %s" % current.data
                current = current.next
        out += "]"

    def __len__(self):
        count = 0
        current = self.head
        while current:
            count += 1
            current = current.next
        return count
# Out:
#   Cell In[13], line 1
#     Class DoublyLinkedList:
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Recursive Function
#
# A recursive function is simply a function that calls itself at least once.
# A basic premise of a recursive function os that the exit condition is typically referred to as the base case, something ultimately knowne to be true in the content of the problem we are solving.

# %% [markdown]
# # Factorial function
#
# # The factorial of a number N is represented as N! and is the product of all of it's preceding intergers from N to 1.
# # As a convention, the factorial of 0 (in other words 0!) is said to be 1.
#
# # 5! = 5x4x3x2x1 = 120
# # 5! = 5x4!
# # 4! = 3x2!
# # ...
#
# def factorial(n):
#     if n == 0:
#     return 1
#     return n*factorials (n-1)

# %% [raw]
# # A classical problem with recursive functions and how to solve it
#
# # Fibonacci
#
# # 0, 1, 1, 2, 3, 5, 8, 13, 21
#
# # F0 = 0
# # F1 = 1
# # Fn = F(n-1) + F(n-2)
#
# from functools import lru_cache
#
# @lru_cache
# def fin(n):
#     if n < 2:
#         return n
#     return fib(n-1) + fib(n-2)

# %%
fib(8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fib(8)
#
# NameError: name 'fib' is not defined

# %%
mydicti = {}

def fib2(n):
    if n < 2:
        return n
    out = mydict.get(n)
    if not out:
        out = fib(n-1) + fib(n-2)
        mydicti[n] = out
    return out

# %%
def fizz_buzz(n):
    out = []
    for number in range(1, n+1):
        temp_str = ""
        if number%3 and number %5:
            temp_str = str(number)
        else:
            if number %3 == 0:
                temp_str += "Fizz"
            if number %5 == 0:
                temp_str += "Buzz"
        out.append(temp_str)
    return out

# %%
Balance paranthese check
